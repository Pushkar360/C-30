# %% [markdown]
# <a href="https://colab.research.google.com/github/Pushkar360/C-30/blob/main/skill_exp_1_to_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# SKILL

# %% [markdown]
# EXP 1

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
red = pd.read_csv('/content/winequality-red.csv', delimiter = ';')
white = pd.read_csv('/content/winequality-white.csv', delimiter = ';')

# %%
red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
red.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
red.shape
# Out:
# (1599, 12)

# %%
red.size
# Out:
# 19188

# %%
white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
white.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %%
white.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
white.shape
# Out:
# (4898, 12)

# %%
white.size
# Out:
# 58776

# %% [markdown]
# Merging wine datasets

# %%
red['type'] = 'red'
white['type'] = 'white'

df = pd.concat([red, white], axis=0, ignore_index=True)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality   type
# 0         9.4        5    red
# 1         9.8        5    red
# 2         9.8        5    red
# 3         9.8        6    red
# 4         9.4        5    red
# ...       ...      ...    ...
# 6492     11.2        6  white
# 6493      9.6        5  white
# 6494      9.4        6  white
# 6495     12.8        7  white
# 6496     11.8        6  white
#
# [6497 rows x 13 columns]

# %% [markdown]
# Exp 2

# %% [markdown]
# Handling missing values

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# type                    0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# type                    0
# dtype: int64

# %% [markdown]
# Dropping dublicate values

# %%
df.duplicated().sum()
# Out:
# 1177

# %%
df.drop_duplicates(inplace = True)
df.duplicated().sum()
# Out:
# 0

# %%
q1 = df["alcohol"].quantile(0.25)
q3 = df["alcohol"].quantile(0.75)

# %%
iqr = q3 - q1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-aeb9552eca99> in <cell line: 0>()
# ----> 1 iqr = q3 - q1
#
# NameError: name 'q3' is not defined

# %%
df = df[(df["alcohol"] > q1 - 1.5 * iqr) & (df["alcohol"] < q3 + 1.5 * iqr)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-b701bacc6528> in <cell line: 0>()
# ----> 1 df = df[(df["alcohol"] > q1 - 1.5 * iqr) & (df["alcohol"] < q3 + 1.5 * iqr)]
#
# NameError: name 'q1' is not defined

# %% [markdown]
# Exp 3

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['type_label_encoded'] = le.fit_transform(df['type'])

# %%
df[['type', 'type_label_encoded']]
# Out:
#        type  type_label_encoded
# 0       red                   0
# 1       red                   0
# 2       red                   0
# 3       red                   0
# 5       red                   0
# ...     ...                 ...
# 6492  white                   1
# 6493  white                   1
# 6494  white                   1
# 6495  white                   1
# 6496  white                   1
#
# [5320 rows x 2 columns]

# %% [markdown]
# One Hot Encoder

# %%
one_hot_encoded = pd.get_dummies(df['type'], prefix='type')

# %%
df = df.join(one_hot_encoded)

# %%
df[['type', 'type_red', 'type_white']]
# Out:
#        type  type_red  type_white
# 0       red      True       False
# 1       red      True       False
# 2       red      True       False
# 3       red      True       False
# 5       red      True       False
# ...     ...       ...         ...
# 6492  white     False        True
# 6493  white     False        True
# 6494  white     False        True
# 6495  white     False        True
# 6496  white     False        True
#
# [5320 rows x 3 columns]

# %% [markdown]
# ordinal  Encoder

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder()

# %%
df['quality_ordinal_encoded'] = oe.fit_transform(df[['quality']])

# %%
df[['quality', 'quality_ordinal_encoded']]
# Out:
#       quality  quality_ordinal_encoded
# 0           5                      2.0
# 1           5                      2.0
# 2           5                      2.0
# 3           6                      3.0
# 5           5                      2.0
# ...       ...                      ...
# 6492        6                      3.0
# 6493        5                      2.0
# 6494        6                      3.0
# 6495        7                      4.0
# 6496        6                      3.0
#
# [5320 rows x 2 columns]

# %% [markdown]
# Target encoder

# %%
import category_encoders as ce
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-36-6021c897e3cf> in <cell line: 0>()
# ----> 1 import category_encoders as ce
#
# ModuleNotFoundError: No module named 'category_encoders'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
te = ce.TargetEncoder(cols=['type'])

# %%
df['type_target_encoded'] = te.fit_transform(df['type'], df['quality'])

# %%
df[["type", "type_target_encoded"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-e31322b50907> in <cell line: 0>()
# ----> 1 df[["type", "type_target_encoded"]]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6250
#    6251             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252             raise KeyError(f"{not_found} not in index")
#    6253
#    6254     @overload
#
# KeyError: "['type_target_encoded'] not in index"

# %% [markdown]
# frequency Encoder

# %%
fe = df['type'].value_counts() / len(df)

# %%
df['type_frequency_encoded'] = df['type'].map(fe)

# %%
df[['type', 'type_frequency_encoded']]
# Out:
#        type  type_frequency_encoded
# 0       red                0.255451
# 1       red                0.255451
# 2       red                0.255451
# 3       red                0.255451
# 5       red                0.255451
# ...     ...                     ...
# 6492  white                0.744549
# 6493  white                0.744549
# 6494  white                0.744549
# 6495  white                0.744549
# 6496  white                0.744549
#
# [5320 rows x 2 columns]

# %% [markdown]
# Binary encoder

# %%
import category_encoders as ce
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-62-6021c897e3cf> in <cell line: 0>()
# ----> 1 import category_encoders as ce
#
# ModuleNotFoundError: No module named 'category_encoders'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
be = ce.BinaryEncoder(cols=['type'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-9f2492a0073d> in <cell line: 0>()
# ----> 1 be = ce.BinaryEncoder(cols=['type'])
#
# NameError: name 'ce' is not defined

# %%
df_binary = be.fit_transform(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-f40a00ce4726> in <cell line: 0>()
# ----> 1 df_binary = be.fit_transform(df)
#
# NameError: name 'be' is not defined

# %%
df_binary[['type_0', 'type_1']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-2369ffa1f685> in <cell line: 0>()
# ----> 1 df_binary[['type_0', 'type_1']]
#
# NameError: name 'df_binary' is not defined

# %% [markdown]
# Exp 4

# %% [markdown]
# mini maxing scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
numeric_cols = df.select_dtypes(include=['float64']).columns

# %%
df = df.copy()

# %%
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.297521          0.413333     0.000000        0.019939   0.111296
# 1       0.330579          0.533333     0.000000        0.030675   0.147841
# 2       0.330579          0.453333     0.024096        0.026074   0.137874
# 3       0.611570          0.133333     0.337349        0.019939   0.109635
# 5       0.297521          0.386667     0.000000        0.018405   0.109635
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.034722              0.064516  0.206092  0.612403   0.191011
# 1             0.083333              0.140553  0.186813  0.372093   0.258427
# 2             0.048611              0.110599  0.190669  0.418605   0.241573
# 3             0.055556              0.124424  0.209948  0.341085   0.202247
# 5             0.041667              0.078341  0.206092  0.612403   0.191011
#
#     alcohol  quality type  type_label_encoded  type_red  type_white  \
# 0  0.202899        5  red                   0      True       False
# 1  0.260870        5  red                   0      True       False
# 2  0.260870        5  red                   0      True       False
# 3  0.260870        6  red                   0      True       False
# 5  0.202899        5  red                   0      True       False
#
#    quality_ordinal_encoded  type_frequency_encoded
# 0                 0.333333                     0.0
# 1                 0.333333                     0.0
# 2                 0.333333                     0.0
# 3                 0.500000                     0.0
# 5                 0.333333                     0.0

# %% [markdown]
# standardization scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
numeric_cols = df.select_dtypes(include=['float64']).columns

# %%
scaled_wines = df.copy()

# %%
scaled_wines[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# %%
scaled_wines.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.140064          2.115349    -2.164515       -0.699699   0.523880
# 1       0.443199          3.185297    -2.164515       -0.544135   1.120736
# 2       0.443199          2.471998    -1.892672       -0.610806   0.957957
# 3       3.019841         -0.381197     1.641293       -0.699699   0.496751
# 5       0.140064          1.877583    -2.164515       -0.721923   0.496751
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -1.069272             -1.411143  1.100996  1.779304   0.177941
# 1            -0.282905             -0.829839  0.763753 -0.153797   0.979389
# 2            -0.844596             -1.058837  0.831202  0.220351   0.779027
# 3            -0.732258             -0.953146  1.168444 -0.403229   0.311515
# 5            -0.956934             -1.305451  1.100996  1.779304   0.177941
#
#     alcohol  quality type  type_label_encoded  type_red  type_white  \
# 0 -0.969152        5  red                   0      True       False
# 1 -0.631833        5  red                   0      True       False
# 2 -0.631833        5  red                   0      True       False
# 3 -0.631833        6  red                   0      True       False
# 5 -0.969152        5  red                   0      True       False
#
#    quality_ordinal_encoded  type_frequency_encoded
# 0                -0.904497               -1.707233
# 1                -0.904497               -1.707233
# 2                -0.904497               -1.707233
# 3                 0.232268               -1.707233
# 5                -0.904497               -1.707233

# %% [markdown]
# Plotting of DATA

# %%
avg_alcohol = df.groupby('quality')['alcohol'].mean().reset_index()

plt.figure(figsize=(8,6))
sns.barplot(x='quality', y='alcohol', data=avg_alcohol, palette='viridis')

plt.title('Average Alcohol Content by Wine Quality', fontsize=16)
plt.xlabel('Quality', fontsize=12)
plt.ylabel('Average Alcohol Content', fontsize=12)

plt.show()
# Out:
# <ipython-input-55-3450c32338ef>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='quality', y='alcohol', data=avg_alcohol, palette='viridis')

# %%
plt.figure(figsize=(8,6))
plt.scatter(df['fixed acidity'], df['pH'], s = 5, alpha=0.5, color='indigo')

plt.title('Fixed Acidity vs pH', fontsize=16)
plt.xlabel('Fixed Acidity', fontsize=12)
plt.ylabel('pH', fontsize=12)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='ocean')

plt.colorbar()

plt.show()

# %%
avg_alcohol = df.groupby('quality')['alcohol'].mean().reset_index()

plt.figure(figsize=(8,6))
sns.barplot(x='quality', y='alcohol', data=avg_alcohol, palette='viridis')

plt.title('Average Alcohol Content by Wine Quality', fontsize=16)
plt.xlabel('Quality', fontsize=12)
plt.ylabel('Average Alcohol Content', fontsize=12)

plt.show()
# Out:
# <ipython-input-58-3450c32338ef>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='quality', y='alcohol', data=avg_alcohol, palette='viridis')

# %%
plt.figure(figsize=(8,6))
plt.hist(df['fixed acidity'], bins=20, alpha=0.7, color='green')

plt.title('Histogram of Fixed Acidity', fontsize=16)
plt.xlabel('Fixed Acidity (g/L)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

plt.show()

# %%
wine_type_counts = df['type'].value_counts()

plt.figure(figsize=(5, 5))
wine_type_counts.plot.pie(autopct='%1.1f%%', colors=['white', 'red'], startangle=90, wedgeprops={'edgecolor': 'black'})

plt.title('Proportion of Red vs White Wines', fontsize=16)

plt.show()
