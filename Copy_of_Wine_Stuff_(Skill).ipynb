# %% [markdown]
# <a href="https://colab.research.google.com/github/Pushkar360/C-30/blob/main/Copy_of_Wine_Stuff_(Skill).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Science using Python**
#
# ---

# %% [markdown]
# ##Experiment 1

# %% [markdown]
# ###Importing Wine Datasets

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
red = pd.read_csv('/content/winequality-red.csv', delimiter = ';')
white = pd.read_csv('/content/winequality-white.csv', delimiter = ';')

# %% [markdown]
# ### Red Dataset Information

# %%
red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
red.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
red.shape
# Out:
# (1599, 12)

# %%
red.size
# Out:
# 19188

# %% [markdown]
# ### White Dataset Information

# %%
white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
white.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %%
white.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
white.shape
# Out:
# (4898, 12)

# %%
white.size
# Out:
# 58776

# %% [markdown]
# ### Merging Wine Datasets

# %%
red['type'] = 'red'
white['type'] = 'white'

df = pd.concat([red, white], axis=0, ignore_index=True)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality   type
# 0         9.4        5    red
# 1         9.8        5    red
# 2         9.8        5    red
# 3         9.8        6    red
# 4         9.4        5    red
# ...       ...      ...    ...
# 6492     11.2        6  white
# 6493      9.6        5  white
# 6494      9.4        6  white
# 6495     12.8        7  white
# 6496     11.8        6  white
#
# [6497 rows x 13 columns]

# %% [markdown]
# ## Experiment 2

# %% [markdown]
# ###Handling Missing Values

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# type                    0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# type                    0
# dtype: int64

# %% [markdown]
# ###Dropping Duplicate Values

# %%
df.duplicated().sum()
# Out:
# np.int64(1177)

# %%
df.drop_duplicates(inplace = True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Handling Outliers

# %%
q1 = df["alcohol"].quantile(0.25)
q3 = df["alcohol"].quantile(0.75)

# %%
iqr = q3 - q1

# %%
df = df[(df["alcohol"] > q1 - 1.5 * iqr) & (df["alcohol"] < q3 + 1.5 * iqr)]

# %% [markdown]
# ## Experiment 3

# %% [markdown]
# ### Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['type_label_encoded'] = le.fit_transform(df['type'])
# Out:
# <ipython-input-23-43fcf52ae86a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['type_label_encoded'] = le.fit_transform(df['type'])

# %%
df[['type', 'type_label_encoded']]
# Out:
#        type  type_label_encoded
# 0       red                   0
# 1       red                   0
# 2       red                   0
# 3       red                   0
# 5       red                   0
# ...     ...                 ...
# 6492  white                   1
# 6493  white                   1
# 6494  white                   1
# 6495  white                   1
# 6496  white                   1
#
# [5319 rows x 2 columns]

# %% [markdown]
# ### One-Hot Encoder

# %%
one_hot_encoded = pd.get_dummies(df['type'], prefix='type')

# %%
df = df.join(one_hot_encoded)

# %%
df[['type', 'type_red', 'type_white']]
# Out:
#        type  type_red  type_white
# 0       red      True       False
# 1       red      True       False
# 2       red      True       False
# 3       red      True       False
# 5       red      True       False
# ...     ...       ...         ...
# 6492  white     False        True
# 6493  white     False        True
# 6494  white     False        True
# 6495  white     False        True
# 6496  white     False        True
#
# [5319 rows x 3 columns]

# %% [markdown]
# ### Ordinal Encoder

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder()

# %%
df['quality_ordinal_encoded'] = oe.fit_transform(df[['quality']])

# %%
df[['quality', 'quality_ordinal_encoded']]
# Out:
#       quality  quality_ordinal_encoded
# 0           5                      2.0
# 1           5                      2.0
# 2           5                      2.0
# 3           6                      3.0
# 5           5                      2.0
# ...       ...                      ...
# 6492        6                      3.0
# 6493        5                      2.0
# 6494        6                      3.0
# 6495        7                      4.0
# 6496        6                      3.0
#
# [5319 rows x 2 columns]

# %% [markdown]
# ### Target Encoder

# %%
# !pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.8.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from category_encoders) (2.0.2)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.11/dist-packages (from category_encoders) (2.2.2)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from category_encoders) (1.0.1)
# Requirement already satisfied: scikit-learn>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from category_encoders) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from category_encoders) (1.14.1)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from category_encoders) (0.14.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.5->category_encoders) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.5->category_encoders) (2025.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.6.0->category_encoders) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.6.0->category_encoders) (3.6.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels>=0.9.0->category_encoders) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.17.0)
# Downloading category_encoders-2.8.1-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.8.1

# %%
import category_encoders as ce

# %%
te = ce.TargetEncoder(cols=['type'])

# %%
df['type_target_encoded'] = te.fit_transform(df['type'], df['quality'])

# %%
df[["type", "type_target_encoded"]]
# Out:
#        type  type_target_encoded
# 0       red             5.623711
# 1       red             5.623711
# 2       red             5.623711
# 3       red             5.623711
# 5       red             5.623711
# ...     ...                  ...
# 6492  white             5.854835
# 6493  white             5.854835
# 6494  white             5.854835
# 6495  white             5.854835
# 6496  white             5.854835
#
# [5319 rows x 2 columns]

# %% [markdown]
# ### Binary Encoder

# %%
import category_encoders as ce

# %%
be = ce.BinaryEncoder(cols=['type'])

# %%
df_binary = be.fit_transform(df)

# %%
df_binary[['type_0', 'type_1']]
# Out:
#       type_0  type_1
# 0          0       1
# 1          0       1
# 2          0       1
# 3          0       1
# 5          0       1
# ...      ...     ...
# 6492       1       0
# 6493       1       0
# 6494       1       0
# 6495       1       0
# 6496       1       0
#
# [5319 rows x 2 columns]

# %% [markdown]
# ### Frequency Encoder

# %%
fe = df['type'].value_counts() / len(df)

# %%
df['type_frequency_encoded'] = df['type'].map(fe)

# %%
df[['type', 'type_frequency_encoded']]
# Out:
#        type  type_frequency_encoded
# 0       red                0.255311
# 1       red                0.255311
# 2       red                0.255311
# 3       red                0.255311
# 5       red                0.255311
# ...     ...                     ...
# 6492  white                0.744689
# 6493  white                0.744689
# 6494  white                0.744689
# 6495  white                0.744689
# 6496  white                0.744689
#
# [5319 rows x 2 columns]

# %% [markdown]
# ## Experiment 4

# %% [markdown]
# ### Min-Max Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
numeric_cols = df.select_dtypes(include=['float64']).columns

# %%
df = df.copy()

# %%
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.305085          0.413333     0.000000        0.019939   0.111296
# 1       0.338983          0.533333     0.000000        0.030675   0.147841
# 2       0.338983          0.453333     0.024096        0.026074   0.137874
# 3       0.627119          0.133333     0.337349        0.019939   0.109635
# 5       0.305085          0.386667     0.000000        0.018405   0.109635
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.034722              0.064516  0.206092  0.612403   0.191011
# 1             0.083333              0.140553  0.186813  0.372093   0.258427
# 2             0.048611              0.110599  0.190669  0.418605   0.241573
# 3             0.055556              0.124424  0.209948  0.341085   0.202247
# 5             0.041667              0.078341  0.206092  0.612403   0.191011
#
#     alcohol  quality type  type_label_encoded  type_red  type_white  \
# 0  0.225806        5  red                   0      True       False
# 1  0.290323        5  red                   0      True       False
# 2  0.290323        5  red                   0      True       False
# 3  0.290323        6  red                   0      True       False
# 5  0.225806        5  red                   0      True       False
#
#    quality_ordinal_encoded  type_target_encoded  type_frequency_encoded
# 0                 0.333333                  0.0                     0.0
# 1                 0.333333                  0.0                     0.0
# 2                 0.333333                  0.0                     0.0
# 3                 0.500000                  0.0                     0.0
# 5                 0.333333                  0.0                     0.0

# %% [markdown]
# ### Standardization Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
numeric_cols = df.select_dtypes(include=['float64']).columns

# %%
scaled_wines = df.copy()

# %%
scaled_wines[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# %%
scaled_wines.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.141867          2.115169    -2.164922       -0.699551   0.524088
# 1       0.446215          3.185018    -2.164922       -0.543997   1.120951
# 2       0.446215          2.471786    -1.892974       -0.610663   0.958170
# 3       3.033171         -0.381144     1.642346       -0.699551   0.496957
# 5       0.141867          1.877425    -2.164922       -0.721773   0.496957
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -1.069277             -1.411230  1.101197  1.779239   0.178379
# 1            -0.282968             -0.829949  0.763952 -0.154103   0.980069
# 2            -0.844618             -1.058938  0.831401  0.220092   0.779646
# 3            -0.732288             -0.953251  1.168646 -0.403567   0.311994
# 5            -0.956947             -1.305542  1.101197  1.779239   0.178379
#
#     alcohol  quality type  type_label_encoded  type_red  type_white  \
# 0 -0.969599        5  red                   0      True       False
# 1 -0.631884        5  red                   0      True       False
# 2 -0.631884        5  red                   0      True       False
# 3 -0.631884        6  red                   0      True       False
# 5 -0.969599        5  red                   0      True       False
#
#    quality_ordinal_encoded  type_target_encoded  type_frequency_encoded
# 0                -0.904652            -1.707861               -1.707861
# 1                -0.904652            -1.707861               -1.707861
# 2                -0.904652            -1.707861               -1.707861
# 3                 0.232094            -1.707861               -1.707861
# 5                -0.904652            -1.707861               -1.707861

# %% [markdown]
# ##Experiments 5 & 6

# %%
avg_alcohol = df.groupby('quality')['alcohol'].mean().reset_index()

plt.figure(figsize=(8,6))
sns.barplot(x='quality', y='alcohol', data=avg_alcohol, palette='viridis')

plt.title('Average Alcohol Content by Wine Quality', fontsize=16)
plt.xlabel('Quality', fontsize=12)
plt.ylabel('Average Alcohol Content', fontsize=12)

plt.show()
# Out:
# <ipython-input-56-3450c32338ef>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='quality', y='alcohol', data=avg_alcohol, palette='viridis')

# %%
plt.figure(figsize=(8,6))
plt.scatter(df['fixed acidity'], df['pH'], s = 5, alpha=0.5, color='indigo')

plt.title('Fixed Acidity vs pH', fontsize=16)
plt.xlabel('Fixed Acidity', fontsize=12)
plt.ylabel('pH', fontsize=12)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='ocean')

plt.colorbar()

plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(df['fixed acidity'], bins=20, alpha=0.7, color='green')

plt.title('Histogram of Fixed Acidity', fontsize=16)
plt.xlabel('Fixed Acidity (g/L)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

plt.show()

# %%
wine_type_counts = df['type'].value_counts()

plt.figure(figsize=(5, 5))
wine_type_counts.plot.pie(autopct='%1.1f%%', colors=['white', 'red'], startangle=90, wedgeprops={'edgecolor': 'black'})

plt.title('Proportion of Red vs White Wines', fontsize=16)

plt.show()

# %% [markdown]
# ## Experiment 7 & 8

# %% [markdown]
# ### Information Gain

# %%
from sklearn.feature_selection import mutual_info_classif

# %%
X = df.drop(columns=["quality", "type", "type_label_encoded", "type_red", "type_white", "quality_ordinal_encoded"])
y = df["type_label_encoded"]

# %%
info_gain = mutual_info_classif(X, y)

# %%
sorted_features = sorted(zip(X.columns, info_gain), key=lambda x: x[1], reverse=True)

# %%
print("Feature Information Gain Scores:")
for feature, score in sorted_features:
    print(f"{feature}: {score:.4f}")
# Out:
# Feature Information Gain Scores:
# type_target_encoded: 0.5702
# type_frequency_encoded: 0.5700
# chlorides: 0.3556
# total sulfur dioxide: 0.3405
# volatile acidity: 0.2309
# residual sugar: 0.2003
# density: 0.1548
# free sulfur dioxide: 0.1528
# sulphates: 0.1524
# fixed acidity: 0.1341
# citric acid: 0.1115
# pH: 0.0599
# alcohol: 0.0114

# %% [markdown]
# ### Chi-Square Test

# %%
from sklearn.feature_selection import SelectKBest, chi2

# %%
X = df.drop(columns=["quality", "type", "type_label_encoded", "type_red", "type_white", "quality_ordinal_encoded"])
y = df["type_label_encoded"]

# %%
chi2_selector = SelectKBest(score_func=chi2, k="all")
chi2_selector.fit(X, y)
# Out:
# SelectKBest(k='all', score_func=<function chi2 at 0x7b5b544b1940>)

# %%
chi2_scores = chi2_selector.scores_

# %%
sorted_features = sorted(zip(X.columns, chi2_scores), key=lambda x: x[1], reverse=True)

# %%
print("Feature Chi-Square Scores:")
for feature, score in sorted_features:
    print(f"{feature}: {score:.4f}")
# Out:
# Feature Chi-Square Scores:
# type_target_encoded: 1358.0000
# type_frequency_encoded: 1358.0000
# total sulfur dioxide: 176.0704
# volatile acidity: 158.3416
# chlorides: 62.7779
# fixed acidity: 53.9329
# sulphates: 51.3160
# free sulfur dioxide: 43.6553
# residual sugar: 40.1941
# density: 22.3705
# pH: 20.3889
# citric acid: 7.4202
# alcohol: 1.6453

# %% [markdown]
# ### Variance Threshold

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
X = df.drop(columns=["quality", "type", "type_label_encoded", "type_red", "type_white", "quality_ordinal_encoded"])

# %%
selector = VarianceThreshold()

# %%
selector.fit(X)
# Out:
# VarianceThreshold()

# %%
feature_variances = selector.variances_

# %%
sorted_features = sorted(zip(X.columns, feature_variances), key=lambda x: x[1], reverse=True)

# %%
print("Feature Variance Scores:")
for feature, score in sorted_features:
    print(f"{feature}: {score:.6f}")
# Out:
# Feature Variance Scores:
# type_target_encoded: 0.190127
# type_frequency_encoded: 0.190127
# alcohol: 0.036495
# total sulfur dioxide: 0.017111
# pH: 0.015450
# volatile acidity: 0.012581
# fixed acidity: 0.012406
# citric acid: 0.007851
# sulphates: 0.007071
# residual sugar: 0.004764
# free sulfur dioxide: 0.003822
# chlorides: 0.003749
# density: 0.003268

# %% [markdown]
# ### Pearson's Coefficient

# %%
X = df.drop(columns=["quality", "type", "type_label_encoded", "type_red", "type_white", "quality_ordinal_encoded"])
y = df["type_label_encoded"]

# %%
correlation_scores = X.corrwith(y)

# %%
sorted_features = sorted(zip(X.columns, correlation_scores.abs()), key=lambda x: x[1], reverse=True)

# %%
print("Feature Correlation Scores:")
for feature, score in sorted_features:
    print(f"{feature}: {score:.4f}")
# Out:
# Feature Correlation Scores:
# type_target_encoded: 1.0000
# type_frequency_encoded: 1.0000
# total sulfur dioxide: 0.6942
# volatile acidity: 0.6455
# chlorides: 0.4994
# sulphates: 0.4900
# fixed acidity: 0.4863
# free sulfur dioxide: 0.4653
# density: 0.4292
# residual sugar: 0.3290
# pH: 0.3116
# citric acid: 0.1846
# alcohol: 0.0590
